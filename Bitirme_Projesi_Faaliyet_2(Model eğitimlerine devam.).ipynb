# %%
# 1. CondaColab'ı kuralım
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:06
# 🔁 Restarting kernel...

# %%
# 2. Google Drive'ı bağlayalım
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 3. 'myenv' ortamını Python 3.11 ile oluşturalım
print("--- Adım 3.1: 'myenv' (Python 3.11) ortamı oluşturuluyor... ---")
# !conda create --name myenv python=3.11 -y

# 4. Gerekli TÜM kütüphaneleri (PyTorch, click, psutil vb.) 'myenv' ortamına kuralım
print("\n--- Adım 3.2: Gerekli kütüphaneler kuruluyor... ---")
# Projenizin ihtiyaç duyduğu tüm paketler:
# !conda run --name myenv conda install -c pytorch -c conda-forge pytorch torchvision click ninja scipy requests imageio pillow psutil -y

# 5. Kurulumu doğrulayalım
print("\n--- Ortam Kurulumu Tamamlandı! ---")
# !conda run --name myenv python --version
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#
#
# zstd-1.5.7           | 554 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 437 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 254 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.14       | 29.4 MB   | :   2% 0.02494106179077062/1 [00:00<00:03,  4.01s/it]
# icu-75.1             | 11.6 MB   | :  24% 0.2350373721999706/1 [00:00<00:00,  2.35it/s]
#
# ...

# %%
import os

print("GELİŞTİRİLMİŞ MODEL EĞİTİMİ) BAŞLATILIYOR!")

# 1. Adım: Ana Proje Yolumu Tanımlayalım
proje_yolu = "/content/drive/MyDrive/TUBITAK_Projesi/"

# 2. Adım: DÜZELTİLMİŞ StyleGAN Kodunun Olduğu Klasöre git diyelim.
stylegan_klasoru = os.path.join(proje_yolu, "stylegan2-ada-pytorch-fixed")

try:
    os.chdir(stylegan_klasoru)
    print(f"Başarıyla 'stylegan2-ada-pytorch-fixed' klasörüne geçildi.")
    print(f"Şu anki klasörüm: {os.getcwd()}")
except Exception as e:
    print(f"KRİTİK HATA: '{stylegan_klasoru}' klasörüne geçilemedi. Hata: {e}")


# 3. Adım: Eğitim Parametrelerimi Ayarlayalım
OUTDIR = os.path.join(proje_yolu, "results")
DATA = os.path.join(proje_yolu, "empresyonizm_256.zip")
RESUME_PKL = "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl"
GPUS = 1
KIMG = 2000
GAMMA = 1
BATCH_SIZE = 16
AUGPIPE = "bgc"

# 4. Adım: Yeni Eğitimi Başlatalım.
print(f"\nVeri Seti: {DATA}")
print(f"Sonuçlar buraya kaydedilecek: {OUTDIR}")
print(f"AYAR: Batch size {BATCH_SIZE} olarak ayarlandı.")
print(f"YENİ AYAR: 'Mode Collapse' önleyici (augpipe={AUGPIPE}) eklendi.")
print("Eğitim başlıyor...")

# 5. Adım: Script'i 'myenv' ORTAMI İÇİNDE çalıştıralım.
# !conda run --name myenv python train.py --outdir={OUTDIR} --data={DATA} --resume={RESUME_PKL} --gpus={GPUS} --kimg={KIMG} --gamma={GAMMA} --batch={BATCH_SIZE} --augpipe={AUGPIPE}
# Out:
# --- FAALİYET 2 (AŞAMA 2: GELİŞTİRİLMİŞ MODEL EĞİTİMİ) BAŞLATILIYOR! ---
# Başarıyla 'stylegan2-ada-pytorch-fixed' klasörüne geçildi.
# Şu anki klasörüm: /content/drive/MyDrive/TUBITAK_Projesi/stylegan2-ada-pytorch-fixed
#
# Veri Seti: /content/drive/MyDrive/TUBITAK_Projesi/empresyonizm_256.zip
# Sonuçlar buraya kaydedilecek: /content/drive/MyDrive/TUBITAK_Projesi/results
# AYAR: Batch size 16 olarak ayarlandı.
# YENİ AYAR: 'Mode Collapse' önleyici (augpipe=bgc) eklendi.
# Eğitim başlıyor...
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/TUBITAK_Projesi/empresyonizm_256.zip",
#     "use_labels": false,
#     "max_size": 683,
#     "xflip": false,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
# ...
